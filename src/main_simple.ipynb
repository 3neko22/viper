# %% [markdown]
# # ViperGPT -- Quick Start
#
# This notebook is meant to be a quick entry into ViperGPT. **Warning:** This notebook will execute arbitrary code on your machine. Proceed at your own risk.
#
# Before running this code, modify any parameters at `configs/my_config.yaml`. For example, you may want to change the BLIP model (`blip_v2_model_type`) from XXL to XL if your GPU does not have enough memory.

# %%
import os
print(os.environ)
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2'
os.environ['CONFIG_NAMES'] = 'config_codellama_q, benchmarks/gqa'
print(os.environ)
# Out:
# environ({'XDG_SESSION_ID': '4442', 'SSL_CERT_FILE': '/etc/pki/ca-trust/extracted/pem/tls-ca-bundle.pem', 'HOST': 'txoronpio', 'SHELL': '/bin/tcsh', 'SSH_CLIENT': '10.254.60.96 51960 22', 'PYTHONUNBUFFERED': '1', 'VSCODE_HANDLES_SIGPIPE': 'true', 'PYTHONIOENCODING': 'utf-8', 'GROUP': 'gonbidatua', 'USER': 'eamor002', 'VSCODE_CLI_REQUIRE_TOKEN': 'fbd21385-b525-415a-b4f2-fe598c029729', 'HOSTTYPE': 'x86_64-linux', 'VIRTUAL_ENV': '/gaueko0/users/eamor002/venvs/viperGPT', 'ELECTRON_RUN_AS_NODE': '1', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_AGENT_FOLDER': '/gaueko0/users/eamor002/.vscode-server', 'PATH': '/gaueko0/users/eamor002/venvs/viperGPT/bin:/usr/local/cuda-12.1/bin:/gaueko0/users/eamor002/venvs/viperGPT/bin:/gaueko0/users/eamor002/.vscode-server/cli/servers/Stable-dc96b837cf6bb4af9cd736aa3af08cf8279f7685/server/bin/remote-cli:/usr/local/bin:/usr/bin:/opt/dell/srvadmin/bin', 'MAIL': '/var/spool/mail/eamor002', 'PWD': '/gaueko0/users/eamor002', 'V
# ...

# %%
from src.main_simple_lib import *
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
my_dataset = datasets.get_dataset(config.dataset)
query=my_dataset.__getitem__(2)['query']
image = my_dataset.__getitem__(2)['image']

# %%
query=my_dataset.__getitem__(0)['query']
image = my_dataset.__getitem__(0)['image']
show_single_image(image)
code = get_code(query)
# Out:
# <PIL.Image.Image image mode=RGB size=400x267>
#   0 def execute_command(image):
#   1     # Return the pizza
#   2     image_patch = ImagePatch(image)
#   3     pizza_patches = image_patch.find("pizza")
#   4     pizza_patches.sort(key=lambda pizza: pizza.horizontal_center)
#   5     pizza_patch = pizza_patches[0]
#   6     # Remember: return the pizza
#   7     return pizza_patch

# %%
result = execute_code(code, image, show_intermediate_steps=True)
# Out:
# <style>.output_wrapper, .output {height:auto !important; max-height:1000000px;}</style>
# Output()
# ───────────────────────────────────────────────────── Line 1 ──────────────────────────────────────────────────────
# image_patch =
# ───────────────────────────────────────────────────── Line 2 ──────────────────────────────────────────────────────
# pizza_patches[0] =
# pizza_patches[1] =
# ───────────────────────────────────────────────────── Line 3 ──────────────────────────────────────────────────────
# pizza_patches[0] =
# pizza_patches[1] =
# ───────────────────────────────────────────────────── Line 4 ──────────────────────────────────────────────────────
# pizza_patch =
# ───────────────────────────────────────────────────── Line 5 ──────────────────────────────────────────────────────
# pizza_patch =
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
my_dataset.__getitem__(2)['answer']
# Out:
# [98.46, 5.019999999999982, 428.0, 202.95]

# %%
predictions = [result]
ground_truth = [my_dataset.__getitem__(0)['answer']]
my_dataset.accuracy(prediction=predictions, ground_truth=ground_truth)
# Out:
# (0.9648938179016113, 1.0)

# %%
im = load_image('https://viper.cs.columbia.edu/static/images/kids_muffins.jpg')
query = 'Drink with zero alcohol'

show_single_image(im)

text= get_code(query)

# Imprimir los nombres de los argumentos posicionales
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0 def execute_command(image):
#   1     # Return the drink
#   2     image_patch = ImagePatch(image)
#   3     drink_patches = image_patch.find("drink")
#   4     drink_patches.sort(key=lambda drink: drink.horizontal_center)
#   5     drink_patch = drink_patches[0]
#   6     # Remember: return the drink
#   7     return drink_patch

# %%
execute_code(text, im, show_intermediate_steps=True)
# Out:
# <style>.output_wrapper, .output {height:auto !important; max-height:1000000px;}</style>
# Output()
# ───────────────────────────────────────────────────── Line 1 ──────────────────────────────────────────────────────
# image_patch =
# Encountered error "No model named glip. The available models are: ['codellama_Q']. Make sure to activate it in the
# configs files" when trying to run with visualizations. Trying from scratch.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/viper/vision_processes.py:196, in forward(model_name, queues, *args, **kwargs)
#     195 try:
# --> 196     out = consumers[model_name](*args, **kwargs) # args: -> no hay en este caso and kwargs: -> (prompt, query)
#     198 except KeyError as e:
#
# ...
