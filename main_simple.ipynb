# %% [markdown]
# # ViperGPT -- Quick Start
#
# This notebook is meant to be a quick entry into ViperGPT. **Warning:** This notebook will execute arbitrary code on your machine. Proceed at your own risk.
#
# Before running this code, modify any parameters at `configs/my_config.yaml`. For example, you may want to change the BLIP model (`blip_v2_model_type`) from XXL to XL if your GPU does not have enough memory.

# %%
import os
print(os.environ)
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['CONFIG_NAMES'] = 'config_codellama_q, benchmarks/okvqa'
print(os.environ)
# Out:
# environ({'XDG_SESSION_ID': '3413', 'SSL_CERT_FILE': '/etc/pki/ca-trust/extracted/pem/tls-ca-bundle.pem', 'HOST': 'txoronpio', 'SHELL': '/bin/tcsh', 'SSH_CLIENT': '10.254.59.203 49749 22', 'PYTHONUNBUFFERED': '1', 'VSCODE_HANDLES_SIGPIPE': 'true', 'PYTHONIOENCODING': 'utf-8', 'GROUP': 'gonbidatua', 'USER': 'eamor002', 'VSCODE_CLI_REQUIRE_TOKEN': 'a0bfb02c-af97-4acd-9c97-ef93a64b00fd', 'HOSTTYPE': 'x86_64-linux', 'VIRTUAL_ENV': '/gaueko0/users/eamor002/venvs/viperGPT', 'ELECTRON_RUN_AS_NODE': '1', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_AGENT_FOLDER': '/gaueko0/users/eamor002/.vscode-server', 'PATH': '/gaueko0/users/eamor002/venvs/viperGPT/bin:/gaueko0/users/eamor002/.vscode-server/cli/servers/Stable-dc96b837cf6bb4af9cd736aa3af08cf8279f7685/server/bin/remote-cli:/usr/local/bin:/usr/bin:/opt/dell/srvadmin/bin', 'MAIL': '/var/spool/mail/eamor002', 'PWD': '/gaueko0/users/eamor002', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'LANG': 'en_US.UTF-8', 'PS1': '(viperGPT) ', 'SSL_CERT_DIR': '/etc/pki/tls/certs', 'SHLVL': '5', 'HOME': '/gaueko0/users/eamor002', 'OSTYPE': 'linux', 'VSCODE_NLS_CONFIG': '{"locale":"en","osLocale":"en","availableLanguages":{}}', 'VENDOR': 'unknown', 'MACHTYPE': 'x86_64', 'LOGNAME': 'eamor002', 'SSH_CONNECTION': '10.254.59.203 49749 158.227.172.118 22', 'VSCODE_IPC_HOOK_CLI': '/run/user/50522/vscode-ipc-ad9a9737-6cc5-472a-9400-91f17fa94a55.sock', 'LESSOPEN': '||/usr/bin/lesspipe.sh %s', 'BROWSER': '/gaueko0/users/eamor002/.vscode-server/cli/servers/Stable-dc96b837cf6bb4af9cd736aa3af08cf8279f7685/server/bin/helpers/browser.sh', 'XDG_RUNTIME_DIR': '/run/user/50522', 'VSCODE_L10N_BUNDLE_LOCATION': '', 'VSCODE_CWD': '/gaueko0/users/eamor002', 'VIRTUAL_ENV_PROMPT': '(viperGPT) ', '_': '/gaueko0/users/eamor002/venvs/viperGPT/bin/python', 'JUPYTER_PATH': '/gaueko0/users/eamor002/.vscode-server/extensions/ms-toolsai.jupyter-2024.4.0-linux-x64/temp/jupyter', 'PYTHON_FROZEN_MODULES': 'on', 'JPY_SESSION_NAME': '/gaueko0/users/eamor002/viper/main_simple-aac296d8-1d9b-45a4-ab8a-80908d5b5aea.ipynb', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'JPY_PARENT_PID': '5673', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'FORCE_COLOR': '1', 'CLICOLOR_FORCE': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline'})
# environ({'XDG_SESSION_ID': '3413', 'SSL_CERT_FILE': '/etc/pki/ca-trust/extracted/pem/tls-ca-bundle.pem', 'HOST': 'txoronpio', 'SHELL': '/bin/tcsh', 'SSH_CLIENT': '10.254.59.203 49749 22', 'PYTHONUNBUFFERED': '1', 'VSCODE_HANDLES_SIGPIPE': 'true', 'PYTHONIOENCODING': 'utf-8', 'GROUP': 'gonbidatua', 'USER': 'eamor002', 'VSCODE_CLI_REQUIRE_TOKEN': 'a0bfb02c-af97-4acd-9c97-ef93a64b00fd', 'HOSTTYPE': 'x86_64-linux', 'VIRTUAL_ENV': '/gaueko0/users/eamor002/venvs/viperGPT', 'ELECTRON_RUN_AS_NODE': '1', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_AGENT_FOLDER': '/gaueko0/users/eamor002/.vscode-server', 'PATH': '/gaueko0/users/eamor002/venvs/viperGPT/bin:/gaueko0/users/eamor002/.vscode-server/cli/servers/Stable-dc96b837cf6bb4af9cd736aa3af08cf8279f7685/server/bin/remote-cli:/usr/local/bin:/usr/bin:/opt/dell/srvadmin/bin', 'MAIL': '/var/spool/mail/eamor002', 'PWD': '/gaueko0/users/eamor002', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'LANG': 'en_US.UTF-8', 'PS1': '(viperGPT) ', 'SSL_CERT_DIR': '/etc/pki/tls/certs', 'SHLVL': '5', 'HOME': '/gaueko0/users/eamor002', 'OSTYPE': 'linux', 'VSCODE_NLS_CONFIG': '{"locale":"en","osLocale":"en","availableLanguages":{}}', 'VENDOR': 'unknown', 'MACHTYPE': 'x86_64', 'LOGNAME': 'eamor002', 'SSH_CONNECTION': '10.254.59.203 49749 158.227.172.118 22', 'VSCODE_IPC_HOOK_CLI': '/run/user/50522/vscode-ipc-ad9a9737-6cc5-472a-9400-91f17fa94a55.sock', 'LESSOPEN': '||/usr/bin/lesspipe.sh %s', 'BROWSER': '/gaueko0/users/eamor002/.vscode-server/cli/servers/Stable-dc96b837cf6bb4af9cd736aa3af08cf8279f7685/server/bin/helpers/browser.sh', 'XDG_RUNTIME_DIR': '/run/user/50522', 'VSCODE_L10N_BUNDLE_LOCATION': '', 'VSCODE_CWD': '/gaueko0/users/eamor002', 'VIRTUAL_ENV_PROMPT': '(viperGPT) ', '_': '/gaueko0/users/eamor002/venvs/viperGPT/bin/python', 'JUPYTER_PATH': '/gaueko0/users/eamor002/.vscode-server/extensions/ms-toolsai.jupyter-2024.4.0-linux-x64/temp/jupyter', 'PYTHON_FROZEN_MODULES': 'on', 'JPY_SESSION_NAME': '/gaueko0/users/eamor002/viper/main_simple-aac296d8-1d9b-45a4-ab8a-80908d5b5aea.ipynb', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'JPY_PARENT_PID': '5673', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'FORCE_COLOR': '1', 'CLICOLOR_FORCE': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'CUDA_VISIBLE_DEVICES': '0', 'CONFIG_NAMES': 'config_codellama_q, benchmarks/okvqa'})

# %%
from main_simple_lib import *
# Out:
# SELECTED CONFIG FILES: config_codellama_q, benchmarks/okvqa
# /gaueko0/users/eamor002/venvs/viperGPT/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# /gaueko0/users/eamor002/venvs/viperGPT/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu.
# Unused kwargs: ['bnb_8bit_compute_dtype', 'attn_implementation', 'device_map']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# /gaueko0/users/eamor002/venvs/viperGPT/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from main_simple_lib import *
#
# File ~/viper/main_simple_lib.py:32
#      29 cache = Memory('cache/' if config.use_cache else None, verbose=0)
#      31 mp.set_start_method('spawn', force=True)
# ---> 32 from vision_processes import forward, finish_all_consumers  # This import loads all the models. May take a while
#      33 from image_patch import *
#      34 from video_segment import *
#
# File ~/viper/vision_processes.py:179
#     177     for process_name_ in model_class_.list_processes():
#     178         if process_name_ in config.load_models and config.load_models[process_name_]:
# --> 179             consumers[process_name_] = make_fn(model_class_, process_name_, counter_)
#     180             counter_ += 1
#     182 queues_in = None
#
# File ~/viper/vision_processes.py:45, in make_fn(model_class, process_name, counter)
#      43 if num_gpus == 0: gpu_number = 0
#      44 else: gpu_number = counter % num_gpus
# ---> 45 model_instance = model_class(gpu_number=gpu_number)
#      47 def _function(*args, **kwargs):
#      48     if process_name != model_class.name:
#
# File ~/viper/vision_models.py:1198, in codeLlamaQ.__init__(self, gpu_number)
#    1187 self.tokenizer.padding_side = 'left'
#    1189 # for gpu_number in range(torch.cuda.device_count()):
#    1190 #     mem_available = torch.cuda.mem_get_info(f'cuda:{gpu_number}')[0]
#    1191 #     if mem_available <= leave_empty * torch.cuda.get_device_properties(gpu_number).total_memory:
#    (...)
#    1196
#    1197 ## Modelu preentrenatuaren Tokia
# -> 1198 self.model = AutoModelForCausalLM.from_pretrained(
#    1199     token_id_name,
#    1200     quantization_config = quantization_config,
#    1201 )
#    1202 self.model.eval()
#    1203 self.pipe = pipeline("text-generation", model=self.model, tokenizer=self.tokenizer)
#
# File ~/venvs/viperGPT/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     568     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     569 )
#
# File ~/venvs/viperGPT/lib/python3.10/site-packages/transformers/modeling_utils.py:3677, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3668     if dtype_orig is not None:
#    3669         torch.set_default_dtype(dtype_orig)
#    3670     (
#    3671         model,
#    3672         missing_keys,
#    3673         unexpected_keys,
#    3674         mismatched_keys,
#    3675         offload_index,
#    3676         error_msgs,
# -> 3677     ) = cls._load_pretrained_model(
#    3678         model,
#    3679         state_dict,
#    3680         loaded_state_dict_keys,  # XXX: rename?
#    3681         resolved_archive_file,
#    3682         pretrained_model_name_or_path,
#    3683         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3684         sharded_metadata=sharded_metadata,
#    3685         _fast_init=_fast_init,
#    3686         low_cpu_mem_usage=low_cpu_mem_usage,
#    3687         device_map=device_map,
#    3688         offload_folder=offload_folder,
#    3689         offload_state_dict=offload_state_dict,
#    3690         dtype=torch_dtype,
#    3691         hf_quantizer=hf_quantizer,
#    3692         keep_in_fp32_modules=keep_in_fp32_modules,
#    3693     )
#    3695 # make sure token embedding weights are still tied if needed
#    3696 model.tie_weights()
#
# File ~/venvs/viperGPT/lib/python3.10/site-packages/transformers/modeling_utils.py:4104, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules)
#    4100                 set_module_tensor_to_device(
#    4101                     model_to_load, key, "cpu", torch.empty(*param.size(), dtype=dtype)
#    4102                 )
#    4103     else:
# -> 4104         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4105             model_to_load,
#    4106             state_dict,
#    4107             loaded_keys,
#    4108             start_prefix,
#    4109             expected_keys,
#    4110             device_map=device_map,
#    4111             offload_folder=offload_folder,
#    4112             offload_index=offload_index,
#    4113             state_dict_folder=state_dict_folder,
#    4114             state_dict_index=state_dict_index,
#    4115             dtype=dtype,
#    4116             hf_quantizer=hf_quantizer,
#    4117             is_safetensors=is_safetensors,
#    4118             keep_in_fp32_modules=keep_in_fp32_modules,
#    4119             unexpected_keys=unexpected_keys,
#    4120         )
#    4121         error_msgs += new_error_msgs
#    4122 else:
#
# File ~/venvs/viperGPT/lib/python3.10/site-packages/transformers/modeling_utils.py:888, in _load_state_dict_into_meta_model(model, state_dict, loaded_state_dict_keys, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, hf_quantizer, is_safetensors, keep_in_fp32_modules, unexpected_keys)
#     886     set_module_tensor_to_device(model, param_name, param_device, **set_module_kwargs)
#     887 else:
# --> 888     hf_quantizer.create_quantized_param(model, param, param_name, param_device, state_dict, unexpected_keys)
#     889     # For quantized modules with FSDP/DeepSpeed Stage 3, we need to quantize the parameter on the GPU
#     890     # and then cast it to CPU to avoid excessive memory usage on each GPU
#     891     # in comparison to the sharded model across GPUs.
#     892     if is_fsdp_enabled() or is_deepspeed_zero3_enabled():
#
# File ~/venvs/viperGPT/lib/python3.10/site-packages/transformers/quantizers/quantizer_bnb_4bit.py:219, in Bnb4BitHfQuantizer.create_quantized_param(self, model, param_value, param_name, target_device, state_dict, unexpected_keys)
#     216         new_value = new_value.T
#     218     kwargs = old_value.__dict__
# --> 219     new_value = bnb.nn.Params4bit(new_value, requires_grad=False, **kwargs).to(target_device)
#     221 module._parameters[tensor_name] = new_value
#
# File ~/venvs/viperGPT/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:191, in Params4bit.to(self, *args, **kwargs)
#     188 device, dtype, non_blocking, convert_to_format = torch._C._nn._parse_to(*args, **kwargs)
#     190 if (device is not None and device.type == "cuda" and self.data.device.type == "cpu"):
# --> 191     return self.cuda(device)
#     192 else:
#     193     if self.quant_state is not None:
#
# File ~/venvs/viperGPT/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:169, in Params4bit.cuda(self, device)
#     167 def cuda(self, device):
#     168     w = self.data.contiguous().half().cuda(device)
# --> 169     w_4bit, quant_state = bnb.functional.quantize_4bit(w, blocksize=self.blocksize, compress_statistics=self.compress_statistics, quant_type=self.quant_type)
#     170     self.data = w_4bit
#     171     self.quant_state = quant_state
#
# File ~/venvs/viperGPT/lib/python3.10/site-packages/bitsandbytes/functional.py:934, in quantize_4bit(A, absmax, out, blocksize, compress_statistics, quant_type)
#     930     absmax = torch.zeros((blocks,), device=A.device, dtype=torch.float32)
#     933 if out is None:
# --> 934     out = torch.zeros(((n+1)//2, 1), dtype=torch.uint8, device=A.device)
#     936 assert blocksize in [4096, 2048, 1024, 512, 256, 128, 64]
#     938 prev_device = pre_call(A.device)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 22.00 MiB. GPU

# %%
# %debug
# Out:
# > /gaueko0/users/eamor002/viper/GLIP/maskrcnn_benchmark/engine/predictor_glip.py(11)<module>()
#       9 from torchvision import transforms as T
#      10 import pdb
# ---> 11 from maskrcnn_benchmark.modeling.detector import build_detection_model
#      12 from maskrcnn_benchmark.utils.checkpoint import DetectronCheckpointer
#      13 from maskrcnn_benchmark.structures.image_list import to_image_list

# %%
im = load_image('https://viper.cs.columbia.edu/static/images/kids_muffins.jpg')
query = 'Drink with zero alcohol'

show_single_image(im)

text= get_code(query)

# Imprimir los nombres de los argumentos posicionales
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0 def execute_command(image):
#   1     # Return the drink
#   2     image_patch = ImagePatch(image)
#   3     drink_patches = image_patch.find("drink")
#   4     drink_patches.sort(key=lambda drink: drink.horizontal_center)
#   5     drink_patch = drink_patches[0]
#   6     # Remember: return the drink
#   7     return drink_patch

# %%
execute_code(text, im, show_intermediate_steps=True)
# Out:
# <style>.output_wrapper, .output {height:auto !important; max-height:1000000px;}</style>
# Output()
# ───────────────────────────────────────────────────── Line 1 ──────────────────────────────────────────────────────
# image_patch =
# Encountered error "No model named glip. The available models are: ['codellama_Q']. Make sure to activate it in the
# configs files" when trying to run with visualizations. Trying from scratch.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/viper/vision_processes.py:196, in forward(model_name, queues, *args, **kwargs)
#     195 try:
# --> 196     out = consumers[model_name](*args, **kwargs) # args: -> no hay en este caso and kwargs: -> (prompt, query)
#     198 except KeyError as e:
#
# KeyError: 'glip'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/viper/main_simple_lib.py:287, in execute_code(code, im, show_intermediate_steps)
#     286     exec(compile(code_line, 'Codex', 'exec'), globals())
# --> 287     result = execute_command(im, my_fig, time_wait_between_lines, syntax)  # The code is created in the exec()
#     288 except Exception as e:
#
# File Codex:4, in execute_command(image, my_fig, time_wait_between_lines, syntax)
#       3 import math
# ----> 4 import sys
#       5 import time
#
# File ~/viper/image_patch.py:144, in ImagePatch.find(self, object_name)
#     142         object_name = 'people'  # GLIP does better at people than person
# --> 144     all_object_coordinates = self.forward('glip', self.cropped_image, object_name)
#     145 if len(all_object_coordinates) == 0:
#
# File ~/viper/image_patch.py:115, in ImagePatch.forward(self, model_name, *args, **kwargs)
#     114 def forward(self, model_name, *args, **kwargs):
# --> 115     return forward(model_name, *args, queues=self.queues, **kwargs)
#
# File ~/viper/vision_processes.py:199, in forward(model_name, queues, *args, **kwargs)
#     198     except KeyError as e:
# --> 199         raise KeyError(error_msg.format(list(consumers.keys()))) from e
#     200 else: # NO INTERESA AHORA
#
# KeyError: "No model named glip. The available models are: ['codellama_Q']. Make sure to activate it in the configs files"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/viper/vision_processes.py:196, in forward(model_name, queues, *args, **kwargs)
#     195 try:
# --> 196     out = consumers[model_name](*args, **kwargs) # args: -> no hay en este caso and kwargs: -> (prompt, query)
#     198 except KeyError as e:
#
# KeyError: 'glip'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 execute_code(text, im, show_intermediate_steps=True)
#
# File ~/viper/main_simple_lib.py:291, in execute_code(code, im, show_intermediate_steps)
#     289         print(f"Encountered error {e} when trying to run with visualizations. Trying from scratch.")
#     290         exec(compile(code, 'Codex', 'exec'), globals())
# --> 291         result = execute_command(im, my_fig, time_wait_between_lines, syntax)  # The code is created in the exec()
#     293     plt.close(my_fig)
#     295 def is_not_fig(x):
#
# File Codex:3, in execute_command(image, my_fig, time_wait_between_lines, syntax)
#       1 # General imports and variables, as well as config
#       2 import ast
# ----> 3 import math
#       4 import sys
#       5 import time
#
# File ~/viper/image_patch.py:144, in ImagePatch.find(self, object_name)
#     141     if object_name == 'person':
#     142         object_name = 'people'  # GLIP does better at people than person
# --> 144     all_object_coordinates = self.forward('glip', self.cropped_image, object_name)
#     145 if len(all_object_coordinates) == 0:
#     146     return []
#
# File ~/viper/image_patch.py:115, in ImagePatch.forward(self, model_name, *args, **kwargs)
#     114 def forward(self, model_name, *args, **kwargs):
# --> 115     return forward(model_name, *args, queues=self.queues, **kwargs)
#
# File ~/viper/vision_processes.py:199, in forward(model_name, queues, *args, **kwargs)
#     196         out = consumers[model_name](*args, **kwargs) # args: -> no hay en este caso and kwargs: -> (prompt, query)
#     198     except KeyError as e:
# --> 199         raise KeyError(error_msg.format(list(consumers.keys()))) from e
#     200 else: # NO INTERESA AHORA
#     201     if queues is None:
#
# KeyError: "No model named glip. The available models are: ['codellama_Q']. Make sure to activate it in the configs files"
